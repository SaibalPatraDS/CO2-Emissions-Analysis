# %%
import pandas as pd
import numpy as np 

import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option("Display.max_rows", 1000)
pd.set_option("Display.max_columns", 25)

# %%
vehicles_data = pd.read_csv("Data/2012-2023 Battery Electric Vehicles.csv")
fuel_consumption_data = pd.read_csv("Data/MY2023 Fuel Consumption Ratings.csv", encoding='cp1252')

# %%
vehicles_data.head()
# Out:
#    Model_Year        Make           Model Vehicle_Class  Motor_kW  \
# 0        2012  Mitsubishi          i-MiEV    Subcompact        49
# 1        2012      Nissan            LEAF      Mid-size        80
# 2        2013        Ford  Focus Electric       Compact       107
# 3        2013  Mitsubishi          i-MiEV    Subcompact        49
# 4        2013      Nissan            LEAF      Mid-size        80
#
#   Transmission Fuel_Type  Consumption_City_kWh/100 km  \
# 0           A1         B                         16.9
# 1           A1         B                         19.3
# 2           A1         B                         19.0
# 3           A1         B                         16.9
# 4           A1         B                         19.3
#
#    Consumption_Hwy_kWh/100 km  Consumption_Comb_kWh/100 km  \
# 0                        21.4                         18.7
# 1                        23.0                         21.1
# ...

# %%
fuel_consumption_data.head()
# Out:
#   Model_Year   Make              Model  Vehicle Class  Engine Size(L)  \
# 0       2023  Acura            Integra      Full-size             1.5
# 1       2023  Acura     Integra A-SPEC      Full-size             1.5
# 2       2023  Acura     Integra A-SPEC      Full-size             1.5
# 3       2023  Acura         MDX SH-AWD     SUV: Small             3.5
# 4       2023  Acura  MDX SH-AWD Type S  SUV: Standard             3.0
#
#    Cylinders Transmission Fuel_Type  Fuel Consumption City (L/100 km)  \
# 0        4.0          AV7         Z                               7.9
# 1        4.0          AV7         Z                               8.1
# 2        4.0           M6         Z                               8.9
# 3        6.0         AS10         Z                              12.6
# 4        6.0         AS10         Z                              13.8
#
#    Hwy (L/100 km)  Comb (L/100 km)  Comb (mpg)  CO2 Emissions(g/km)  \
# ...

# %% [markdown]
# ### Basic Data Preprocessing and EDA

# %%
vehicles_data.columns
# Out:
# Index(['Model_Year', 'Make', 'Model', 'Vehicle_Class', 'Motor_kW',
#        'Transmission', 'Fuel_Type', 'Consumption_City_kWh/100 km',
#        'Consumption_Hwy_kWh/100 km', 'Consumption_Comb_kWh/100 km',
#        'Consumption_City_Le/100 km', 'Consumption_Hwy_Le/100 km',
#        'Consumption_Comb_Le/100 km', 'Range_km', 'CO2 Emissions_g/km',
#        'CO2_rating', 'Smog_rating', 'Recharge_time_h'],
#       dtype='object')

# %%
vehicles_data.head(1)
# Out:
#    Model_Year        Make   Model Vehicle_Class  Motor_kW Transmission  \
# 0        2012  Mitsubishi  i-MiEV    Subcompact        49           A1
#
#   Fuel_Type  Consumption_City_kWh/100 km  Consumption_Hwy_kWh/100 km  \
# 0         B                         16.9                        21.4
#
#    Consumption_Comb_kWh/100 km  Consumption_City_Le/100 km  \
# 0                         18.7                         1.9
#
#    Consumption_Hwy_Le/100 km  Consumption_Comb_kWh/100 km.1  Range_km  \
# 0                        2.4                            2.1       100
#
#    CO2 Emissions_g/km  CO2_rating  Smog_rating  Recharge_time_h
# 0                   0         NaN          NaN              7.0

# %%
vehicles_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 411 entries, 0 to 410
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Model_Year                     411 non-null    int64
#  1   Make                           411 non-null    object
#  2   Model                          411 non-null    object
#  3   Vehicle_Class                  411 non-null    object
#  4   Motor_kW                       411 non-null    int64
#  5   Transmission                   411 non-null    object
#  6   Fuel_Type                      411 non-null    object
#  7   Consumption_City_kWh/100 km    411 non-null    float64
#  8   Consumption_Hwy_kWh/100 km     411 non-null    float64
#  9   Consumption_Comb_kWh/100 km    411 non-null    float64
#  10  Consumption_City_Le/100 km     411 non-null    float64
#  11  Consumption_Hwy_Le/100 km      411 non-null    float64
# ...

# %% [raw]
# Vehicles Company and Making Year

# %%
vehicles_data['Model_Year'].value_counts(normalize = True) * 100
# Out:
# 2023    24.330900
# 2022    19.951338
# 2021    11.922141
# 2020     9.732360
# 2019     8.515815
# 2016     6.569343
# 2017     5.596107
# 2018     5.109489
# 2015     3.406326
# 2013     2.189781
# 2014     2.189781
# 2012     0.486618
# Name: Model_Year, dtype: float64

# %%
vehicles_data.Make.value_counts()[:10]
# Out:
# Tesla        132
# BMW           36
# Ford          31
# Kia           26
# Porsche       21
# Nissan        20
# Audi          18
# Hyundai       16
# Lucid         15
# Chevrolet     12
# Name: Make, dtype: int64

# %%
vehicles_data.groupby(['Make', 'Model'])['Model'].count()
# Out:
# Make           Model
# Audi           Q4 50 e-tron Sportback quattro                     1
#                Q4 50 e-tron quattro                               2
#                Q4 Sportback 50 e-tron quattro                     1
#                RS e-tron GT                                       2
#                e-tron 55 quattro                                  4
#                e-tron GT                                          2
#                e-tron S Sportback quattro (20" Wheels)            1
#                e-tron S Sportback quattro (21" or 22" Wheels)     1
#                e-tron Sportback 55 quattro                        4
# BMW            i3                                                 3
#                i3 (120 Ah)                                        3
#                i3 (60 Ah)                                         1
#                i3 (94 Ah)                                         1
# ...

# %%
vehicles_data.columns
# Out:
# Index(['Model_Year', 'Make', 'Model', 'Vehicle_Class', 'Motor_kW',
#        'Transmission', 'Fuel_Type', 'Consumption_City_kWh/100 km',
#        'Consumption_Hwy_kWh/100 km', 'Consumption_Comb_kWh/100 km',
#        'Consumption_City_Le/100 km', 'Consumption_Hwy_Le/100 km',
#        'Consumption_Comb_kWh/100 km.1', 'Range_km', 'CO2 Emissions_g/km',
#        'CO2_rating', 'Smog_rating', 'Recharge_time_h'],
#       dtype='object')

# %%
vehicles_data['Fuel_Type'].value_counts()   #unique fuel types, only electricity
# Out:
# B    411
# Name: Fuel_Type, dtype: int64

# %%
vehicles_data['Vehicle_Class'].value_counts()
# Out:
# Full-size                 93
# Mid-size                  77
# SUV: Standard             63
# SUV: Small                58
# Station wagon: Small      41
# Subcompact                35
# Compact                   22
# Two-seater                12
# Pickup truck: Standard    10
# Name: Vehicle_Class, dtype: int64

# %% [raw]
# Which company is providing most full-size cars?

# %%
vehicles_data.query("`Vehicle_Class` == 'Full-size'")['Make'].value_counts().reset_index().rename(
    columns = {'index': "Company", 'Make':'No of Cars'}
)[:1]
# Out:
#   Company  No of Cars
# 0   Tesla          62
